# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
df_org= pd.read_csv("TV.csv")
df_org.head()
# Out:
#   Product_Name  Stars  Ratings  Reviews  current_price    MRP  \
# 0        Croma    4.2     1773      217           7990  20000
# 1        Adsun    3.8     6742      930           8699  21999
# 2           LG    4.4    38870     3443          16499  21990
# 3      OnePlus    4.3   101256     9189          16499  21999
# 4       Xiaomi    4.3     3120      305          15499  24999
#
#                                       channel  \
# 0                  HD Ready 1366 x 768 Pixels
# 1              Netflix|Disney+Hotstar|Youtube
# 2  Netflix|Prime Video|Disney+Hotstar|Youtube
# 3  Netflix|Prime Video|Disney+Hotstar|Youtube
# 4  Netflix|Prime Video|Disney+Hotstar|Youtube
#
#                   Operating_system             Picture_qualtiy  \
# 0                20 Speaker Output          60 Hz Refresh Rate
# 1  Operating System: Android Based  HD Ready 1366 x 768 Pixels
# 2          Operating System: WebOS  HD Ready 1366 x 768 Pixels
# ...

# %%
df1=df_org.copy()
df1=df1[["Picture_qualtiy","Speaker","Frequency"]]
df1
# Out:
#                       Picture_qualtiy              Speaker           Frequency
# 0                  60 Hz Refresh Rate   2 x HDMI | 2 x USB     1 Year Warranty
# 1          HD Ready 1366 x 768 Pixels  20 W Speaker Output  60 Hz Refresh Rate
# 2          HD Ready 1366 x 768 Pixels  10 W Speaker Output  50 Hz Refresh Rate
# 3          HD Ready 1366 x 768 Pixels  20 W Speaker Output  60 Hz Refresh Rate
# 4          HD Ready 1366 x 768 Pixels  20 W Speaker Output  60 Hz Refresh Rate
# ..                                ...                  ...                 ...
# 661                60 Hz Refresh Rate   2 x HDMI | 1 x USB              1 YEAR
# 662  Ultra HD (4K) 3840 x 2160 Pixels  20 W Speaker Output  50 Hz Refresh Rate
# 663                60 Hz Refresh Rate   2 x HDMI | 2 x USB    3 Years Warranty
# 664                 16 Speaker Output   50 Hz Refresh Rate  2 x HDMI | 2 x USB
# 665                50 Hz Refresh Rate   2 x HDMI | 2 x USB              1 YEAR
#
# [666 rows x 3 columns]

# %%
col = ['Picture_qualtiy','Speaker','Frequency']
a=0
for i in col:
    a+=df1[i].map(lambda x : "60 Hz" in x).sum()
print(a)
# Out:
# 510

# %%
df1.apply(lambda s: s.str.contains("Hz")).sum()
# Out:
# Picture_qualtiy     99
# Speaker             23
# Frequency          540
# dtype: int64

# %%
df2=df_org[["Stars","Operating_system","channel","Picture_qualtiy"]]
df2.head()
# Out:
#    Stars                 Operating_system  \
# 0    4.2                20 Speaker Output
# 1    3.8  Operating System: Android Based
# 2    4.4          Operating System: WebOS
# 3    4.3        Operating System: Android
# 4    4.3        Operating System: Android
#
#                                       channel             Picture_qualtiy
# 0                  HD Ready 1366 x 768 Pixels          60 Hz Refresh Rate
# 1              Netflix|Disney+Hotstar|Youtube  HD Ready 1366 x 768 Pixels
# 2  Netflix|Prime Video|Disney+Hotstar|Youtube  HD Ready 1366 x 768 Pixels
# 3  Netflix|Prime Video|Disney+Hotstar|Youtube  HD Ready 1366 x 768 Pixels
# 4  Netflix|Prime Video|Disney+Hotstar|Youtube  HD Ready 1366 x 768 Pixels

# %%
col = ['Operating_system','channel','Picture_qualtiy']


d_4_0 = df1.loc[df1['Operating_system'].map(lambda x : "4K" in x),'Stars']
d_4_1 = df1.loc[df1['channel'].map(lambda x : "4K" in x),'Stars']
d_4_2 = df1.loc[df1['Picture_qualtiy'].map(lambda x : "4K" in x),'Stars']
d_4 = pd.concat([d_4_0,d_4_1,d_4_2])
d_8_0 = df1.loc[df1['Operating_system'].map(lambda x : "8K" in x),'Stars']
d_8_1 = df1.loc[df1['channel'].map(lambda x : "8K" in x),'Stars']
d_8_2 = df1.loc[df1['Picture_qualtiy'].map(lambda x : "8K" in x),'Stars']
d_4 = pd.concat([d_4_0,d_4_1,d_4_2])
d_8 = pd.concat([d_8_0,d_8_1,d_8_2])
round(abs(d_4.mean()-d_8.mean()),2)
# Out:
# 0.38

# %%
col = ['Operating_system','channel','Picture_qualtiy']
df2=df_org[col].copy()
df2
# Out:
#                     Operating_system  \
# 0                  20 Speaker Output
# 1    Operating System: Android Based
# 2            Operating System: WebOS
# 3          Operating System: Android
# 4          Operating System: Android
# ..                               ...
# 661                NO Speaker Output
# 662    Operating System: Linux based
# 663                20 Speaker Output
# 664       Full HD 1920 x 1080 Pixels
# 665         10W + 10W Speaker Output
#
#                                                channel  \
# 0                           HD Ready 1366 x 768 Pixels
# 1                       Netflix|Disney+Hotstar|Youtube
# 2           Netflix|Prime Video|Disney+Hotstar|Youtube
# 3           Netflix|Prime Video|Disney+Hotstar|Youtube
# 4           Netflix|Prime Video|Disney+Hotstar|Youtube
# ..                                                 ...
# 661            Ultra HD (4K) 3840 x 2160 pixels Pixels
# 662                        Netflix|Prime Video|Youtube
# ...

# %%
df2.apply(lambda x: x.str.contains("4K|8K"))
# Out:
#      Operating_system  channel  Picture_qualtiy
# 0               False    False            False
# 1               False    False            False
# 2               False    False            False
# 3               False    False            False
# 4               False    False            False
# ..                ...      ...              ...
# 661             False     True            False
# 662             False    False             True
# 663             False    False            False
# 664             False    False            False
# 665             False     True            False
#
# [666 rows x 3 columns]

# %%
df2[~df2.apply(lambda x: x.str.contains("4K|8K"))]
# Out:
#                     Operating_system  \
# 0                  20 Speaker Output
# 1    Operating System: Android Based
# 2            Operating System: WebOS
# 3          Operating System: Android
# 4          Operating System: Android
# ..                               ...
# 661                NO Speaker Output
# 662    Operating System: Linux based
# 663                20 Speaker Output
# 664       Full HD 1920 x 1080 Pixels
# 665         10W + 10W Speaker Output
#
#                                                channel  \
# 0                           HD Ready 1366 x 768 Pixels
# 1                       Netflix|Disney+Hotstar|Youtube
# 2           Netflix|Prime Video|Disney+Hotstar|Youtube
# 3           Netflix|Prime Video|Disney+Hotstar|Youtube
# 4           Netflix|Prime Video|Disney+Hotstar|Youtube
# ..                                                 ...
# 661                                                NaN
# 662                        Netflix|Prime Video|Youtube
# ...

# %%
df2.apply(lambda x: x.str.contains("4K|8K")).sum(axis=1)>1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 661    False
# 662    False
# 663    False
# 664    False
# 665    False
# Length: 666, dtype: bool

# %%
df2['is_4K']=df2[col].apply(lambda x: x.str.contains("4K")).sum(axis=1)>1
# df2['is_8K']=df2.apply(lambda x: x.str.contains("8K")).sum(axis=1)>1
#df2

# %%
col = ['Operating_system','channel','Picture_qualtiy']
d_4 = pd.

# %%
df_org.head(10)
# Out:
#   Product_Name  Stars  Ratings  Reviews  current_price    MRP  \
# 0        Croma    4.2     1773      217           7990  20000
# 1        Adsun    3.8     6742      930           8699  21999
# 2           LG    4.4    38870     3443          16499  21990
# 3      OnePlus    4.3   101256     9189          16499  21999
# 4       Xiaomi    4.3     3120      305          15499  24999
# 5      SAMSUNG    4.4    53639     4811          15999  22900
# 6      OnePlus    4.3   101256     9189          15499  19999
# 7        Croma    4.2        0        0          11990  25000
# 8           LG    4.4     5830      698          32990  59990
# 9      OnePlus    4.3   101256     9189          25999  31999
#
#                                       channel  \
# 0                  HD Ready 1366 x 768 Pixels
# 1              Netflix|Disney+Hotstar|Youtube
# 2  Netflix|Prime Video|Disney+Hotstar|Youtube
# 3  Netflix|Prime Video|Disney+Hotstar|Youtube
# 4  Netflix|Prime Video|Disney+Hotstar|Youtube
# ...

# %%
d1=df_org["channel"].map(lambda x : not "Pixels" in x)
d2=df_org["Operating_system"].map(lambda x : not "Operating" in x)
df2=df_org.loc[d1&d2,]
print(d2.sum())
df2.head(5)
# Out:
# 123
#     Product_Name  Stars  Ratings  Reviews  current_price    MRP  \
# 158          TCL    4.4        0        0          34990  62990
# 196          TCL    4.4        0        0          28215  51990
# 242           LG    4.3     1124      111          18999  20490
# 297          TCL    4.2        0        0          55499  89900
# 315           LG    4.3        0        0          64999  93990
#
#                                         channel  \
# 158  Netflix|Prime Video|Disney+Hotstar|Youtube
# 196  Netflix|Prime Video|Disney+Hotstar|Youtube
# 242                     Operating System: Linux
# 297                   Operating System: Android
# 315                     Operating System: WebOS
#
#                      Operating_system      Picture_qualtiy  \
# 158    Ultra HD (4K) 3840x2160 Pixels   24W Speaker Output
# 196    Ultra HD (4K) 3840x2160 Pixels   24W Speaker Output
# 242        HD Ready 1366 x 768 Pixels  20 W Speaker Output
# ...

# %%
df.Picture_qualtiy
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-a03377da9791> in <module>
# ----> 1 df.Picture_qualtiy
#
# D:\khlee\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'Picture_qualtiy'

# %%
df1=df['Picture_qualtiy'].str.contains("Hz")
# df2=df['Speaker'].str.contains("Hz")
# df=df.loc[df1,'Picture_qualtiy']
# df=df.loc[df1,'Speaker']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\khlee\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Picture_qualtiy'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-e9beda6f5c8a> in <module>
# ----> 1 df1=df['Picture_qualtiy'].str.contains("Hz")
#       2 # df2=df['Speaker'].str.contains("Hz")
# ...

# %% [markdown]
# Q3

# %%
df3 =df_org.copy()
df3=df3.loc[~(df3['channel'].str.contains("Pixels|Oper"))]
df3=df3.assign(support_netflix=df3['channel'].str.contains("Netflix").astype(int),
           support_prime=df3['channel'].str.contains("Prime Video").astype(int))

# %%
df3=df3.assign(review_ration=df3.Reviews/df3.Ratings,
          discount_rate=df3.current_price/df3.MRP,
          is_high=df3.Picture_qualtiy.str.contains("4K}8K"))
df3.shape
# Out:
# (548, 16)

# %%
col_f =
